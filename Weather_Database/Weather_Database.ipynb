# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# Import the time library
import time

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set the numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | oussouye
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | puksoozero
# Processing Record 5 of Set 1 | keuruu
# Processing Record 6 of Set 1 | nelson bay
# Processing Record 7 of Set 1 | la ronge
# Processing Record 8 of Set 1 | richards bay
# Processing Record 9 of Set 1 | kungurtug
# Processing Record 10 of Set 1 | puerto escondido
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | simao
# Processing Record 13 of Set 1 | mackenzie
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | yuci
# Processing Record 16 of Set 1 | pafos
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | burns lake
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | qaqortoq
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | makat
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | isangel
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | jibuti
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | leningradskiy
# Processing Record 37 of Set 1 | codrington
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 1 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 42 of Set 1 | quang ngai
# Processing Record 43 of Set 1 | carroll
# Processing Record 44 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | port blair
# Processing Record 48 of Set 1 | valparaiso
# Processing Record 49 of Set 1 | wilmington
# Processing Record 50 of Set 1 | skibbereen
# Processing Record 1 of Set 2 | awjilah
# Processing Record 2 of Set 2 | deputatskiy
# Processing Record 3 of Set 2 | axim
# Processing Record 4 of Set 2 | asau
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | aklavik
# Processing Record 7 of Set 2 | saint-augustin
# Processing Record 8 of Set 2 | coronon
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | kilis
# Processing Record 11 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 2 | ecoporanga
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | tual
# Processing Record 15 of Set 2 | pierre
# Processing Record 16 of Set 2 | aromashevo
# Processing Record 17 of Set 2 | kloulklubed
# Processing Record 18 of Set 2 | kirakira
# Processing Record 19 of Set 2 | flinders
# Processing Record 20 of Set 2 | svetlyy
# Processing Record 21 of Set 2 | palmer
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | mountrath
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | nantucket
# Processing Record 27 of Set 2 | lola
# Processing Record 28 of Set 2 | khromtau
# Processing Record 29 of Set 2 | sisimiut
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | usinsk
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | belaya gora
# Processing Record 34 of Set 2 | lorengau
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | lazaro cardenas
# Processing Record 39 of Set 2 | ilo
# Processing Record 40 of Set 2 | marsh harbour
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | anagni
# Processing Record 44 of Set 2 | bouca
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | oulu
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | muros
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | jennings
# Processing Record 2 of Set 3 | marrakesh
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | caravelas
# Processing Record 5 of Set 3 | a
# City not found. Skipping...
# Processing Record 6 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 3 | vardo
# Processing Record 8 of Set 3 | ust-nera
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | padang
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | kodiak
# Processing Record 13 of Set 3 | dryden
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | soe
# Processing Record 17 of Set 3 | teya
# Processing Record 18 of Set 3 | roald
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | kitimat
# Processing Record 22 of Set 3 | conceicao da barra
# Processing Record 23 of Set 3 | mackay
# Processing Record 24 of Set 3 | vostok
# Processing Record 25 of Set 3 | harper
# Processing Record 26 of Set 3 | lamar
# Processing Record 27 of Set 3 | klaksvik
# Processing Record 28 of Set 3 | hibbing
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | wrexham
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | berlevag
# Processing Record 33 of Set 3 | preobrazheniye
# Processing Record 34 of Set 3 | torbat-e jam
# Processing Record 35 of Set 3 | malangwa
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | linhares
# Processing Record 38 of Set 3 | verkhnyaya toyma
# Processing Record 39 of Set 3 | mount gambier
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | oranjestad
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | xiongyue
# Processing Record 45 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 3 | luderitz
# Processing Record 47 of Set 3 | esperance
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | kalmunai
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | guerrero negro
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | egvekinot
# Processing Record 4 of Set 4 | garowe
# Processing Record 5 of Set 4 | geraldton
# Processing Record 6 of Set 4 | batagay-alyta
# Processing Record 7 of Set 4 | dharchula
# Processing Record 8 of Set 4 | bluff
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | salalah
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | khilok
# Processing Record 13 of Set 4 | kearney
# Processing Record 14 of Set 4 | komsomolskiy
# Processing Record 15 of Set 4 | hami
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 4 | havelock
# Processing Record 19 of Set 4 | chumphon
# Processing Record 20 of Set 4 | san cristobal
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | salamanca
# Processing Record 23 of Set 4 | bud
# Processing Record 24 of Set 4 | mareeba
# Processing Record 25 of Set 4 | bac can
# City not found. Skipping...
# Processing Record 26 of Set 4 | kamiiso
# Processing Record 27 of Set 4 | aksu
# Processing Record 28 of Set 4 | nyzy
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | lompoc
# Processing Record 31 of Set 4 | talcahuano
# Processing Record 32 of Set 4 | garissa
# Processing Record 33 of Set 4 | iwanai
# Processing Record 34 of Set 4 | mpophomeni
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | chuguyevka
# Processing Record 37 of Set 4 | alta floresta
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | bairiki
# Processing Record 41 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 4 | butaritari
# Processing Record 43 of Set 4 | bereda
# Processing Record 44 of Set 4 | paisley
# Processing Record 45 of Set 4 | itarema
# Processing Record 46 of Set 4 | saskylakh
# Processing Record 47 of Set 4 | saint-joseph
# Processing Record 48 of Set 4 | itacare
# Processing Record 49 of Set 4 | vaitape
# Processing Record 50 of Set 4 | amberley
# Processing Record 1 of Set 5 | avanigadda
# Processing Record 2 of Set 5 | balabac
# Processing Record 3 of Set 5 | limpapa
# Processing Record 4 of Set 5 | thinadhoo
# Processing Record 5 of Set 5 | sofiyivka
# Processing Record 6 of Set 5 | avarua
# Processing Record 7 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 5 | point pedro
# Processing Record 9 of Set 5 | hobyo
# Processing Record 10 of Set 5 | amahai
# Processing Record 11 of Set 5 | sechura
# Processing Record 12 of Set 5 | vila velha
# Processing Record 13 of Set 5 | hualmay
# Processing Record 14 of Set 5 | uruacu
# Processing Record 15 of Set 5 | almaznyy
# Processing Record 16 of Set 5 | kenai
# Processing Record 17 of Set 5 | tandil
# Processing Record 18 of Set 5 | qaanaaq
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | clyde river
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | petrovice u karvine
# Processing Record 23 of Set 5 | havoysund
# Processing Record 24 of Set 5 | tessalit
# Processing Record 25 of Set 5 | taksimo
# Processing Record 26 of Set 5 | mount pleasant
# Processing Record 27 of Set 5 | shakawe
# Processing Record 28 of Set 5 | dukat
# Processing Record 29 of Set 5 | porto nacional
# Processing Record 30 of Set 5 | tuatapere
# Processing Record 31 of Set 5 | sobolevo
# Processing Record 32 of Set 5 | pisco
# Processing Record 33 of Set 5 | korla
# Processing Record 34 of Set 5 | vila franca do campo
# Processing Record 35 of Set 5 | pacific grove
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | shingu
# Processing Record 38 of Set 5 | kontagora
# Processing Record 39 of Set 5 | bolivar
# Processing Record 40 of Set 5 | pathein
# Processing Record 41 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 5 | saint george
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | cherskiy
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | torbay
# Processing Record 48 of Set 5 | majene
# Processing Record 49 of Set 5 | beeville
# Processing Record 50 of Set 5 | mastic beach
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 6 | dunedin
# Processing Record 3 of Set 6 | bowen
# Processing Record 4 of Set 6 | cedar city
# Processing Record 5 of Set 6 | addi ugri
# City not found. Skipping...
# Processing Record 6 of Set 6 | rio grande
# Processing Record 7 of Set 6 | poronaysk
# Processing Record 8 of Set 6 | port elizabeth
# Processing Record 9 of Set 6 | zwedru
# Processing Record 10 of Set 6 | tucuma
# Processing Record 11 of Set 6 | bethel
# Processing Record 12 of Set 6 | ponta do sol
# Processing Record 13 of Set 6 | xiashi
# Processing Record 14 of Set 6 | solnechnyy
# Processing Record 15 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 6 | sarkand
# Processing Record 18 of Set 6 | okakarara
# Processing Record 19 of Set 6 | kieta
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | kungsbacka
# Processing Record 22 of Set 6 | tomaszow mazowiecki
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 6 | hondo
# Processing Record 26 of Set 6 | rassvet
# Processing Record 27 of Set 6 | davila
# Processing Record 28 of Set 6 | ust-kuyga
# Processing Record 29 of Set 6 | hervey bay
# Processing Record 30 of Set 6 | cabadiangan
# Processing Record 31 of Set 6 | karratha
# Processing Record 32 of Set 6 | nieuw amsterdam
# Processing Record 33 of Set 6 | alofi
# Processing Record 34 of Set 6 | general roca
# Processing Record 35 of Set 6 | camaqua
# Processing Record 36 of Set 6 | ranong
# Processing Record 37 of Set 6 | pevek
# Processing Record 38 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 6 | ribeira grande
# Processing Record 40 of Set 6 | xichang
# Processing Record 41 of Set 6 | kafr sawm
# Processing Record 42 of Set 6 | varva
# Processing Record 43 of Set 6 | olafsvik
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | bubaque
# Processing Record 46 of Set 6 | jaguarari
# Processing Record 47 of Set 6 | tiznit
# Processing Record 48 of Set 6 | hwange
# Processing Record 49 of Set 6 | maniitsoq
# Processing Record 50 of Set 6 | flin flon
# Processing Record 1 of Set 7 | tombouctou
# Processing Record 2 of Set 7 | mayo
# Processing Record 3 of Set 7 | filadelfia
# Processing Record 4 of Set 7 | pangnirtung
# Processing Record 5 of Set 7 | the valley
# Processing Record 6 of Set 7 | thompson
# Processing Record 7 of Set 7 | vanimo
# Processing Record 8 of Set 7 | barcelona
# Processing Record 9 of Set 7 | parainen
# Processing Record 10 of Set 7 | ostrovnoy
# Processing Record 11 of Set 7 | siraha
# Processing Record 12 of Set 7 | les escoumins
# Processing Record 13 of Set 7 | aguimes
# Processing Record 14 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 7 | shimoda
# Processing Record 16 of Set 7 | inhambane
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 7 | severo-yeniseyskiy
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | bolobo
# Processing Record 22 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 23 of Set 7 | igarka
# Processing Record 24 of Set 7 | sorland
# Processing Record 25 of Set 7 | katsina
# Processing Record 26 of Set 7 | victor harbor
# Processing Record 27 of Set 7 | acapulco
# Processing Record 28 of Set 7 | mildura
# Processing Record 29 of Set 7 | sao joao da barra
# Processing Record 30 of Set 7 | progreso
# Processing Record 31 of Set 7 | terra santa
# Processing Record 32 of Set 7 | san quintin
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | kendari
# Processing Record 35 of Set 7 | buraydah
# Processing Record 36 of Set 7 | vila
# Processing Record 37 of Set 7 | sur
# Processing Record 38 of Set 7 | laguna
# Processing Record 39 of Set 7 | hvide sande
# Processing Record 40 of Set 7 | tarragona
# Processing Record 41 of Set 7 | bosilegrad
# Processing Record 42 of Set 7 | khandyga
# Processing Record 43 of Set 7 | namibe
# Processing Record 44 of Set 7 | port lincoln
# Processing Record 45 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 7 | mokrous
# Processing Record 47 of Set 7 | jiangmen
# Processing Record 48 of Set 7 | maneadero
# Processing Record 49 of Set 7 | porto novo
# Processing Record 50 of Set 7 | honningsvag
# Processing Record 1 of Set 8 | san jeronimo
# Processing Record 2 of Set 8 | morant bay
# Processing Record 3 of Set 8 | gornopravdinsk
# Processing Record 4 of Set 8 | skjervoy
# Processing Record 5 of Set 8 | sapa
# Processing Record 6 of Set 8 | gimbi
# Processing Record 7 of Set 8 | port macquarie
# Processing Record 8 of Set 8 | palmas bellas
# Processing Record 9 of Set 8 | balkanabat
# Processing Record 10 of Set 8 | trabzon
# Processing Record 11 of Set 8 | aswan
# Processing Record 12 of Set 8 | ahipara
# Processing Record 13 of Set 8 | grand gaube
# Processing Record 14 of Set 8 | delvine
# Processing Record 15 of Set 8 | sawai madhopur
# Processing Record 16 of Set 8 | fairbanks
# Processing Record 17 of Set 8 | tamandare
# Processing Record 18 of Set 8 | samarinda
# Processing Record 19 of Set 8 | iquique
# Processing Record 20 of Set 8 | north bend
# Processing Record 21 of Set 8 | agadir
# Processing Record 22 of Set 8 | hohhot
# Processing Record 23 of Set 8 | shellbrook
# Processing Record 24 of Set 8 | biak
# Processing Record 25 of Set 8 | la union
# Processing Record 26 of Set 8 | constitucion
# Processing Record 27 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 28 of Set 8 | keflavik
# Processing Record 29 of Set 8 | benguela
# Processing Record 30 of Set 8 | half moon bay
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | kamenka
# Processing Record 33 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 8 | namtsy
# Processing Record 35 of Set 8 | joao pinheiro
# Processing Record 36 of Set 8 | ojinaga
# Processing Record 37 of Set 8 | ancud
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | westport
# Processing Record 40 of Set 8 | ruwi
# Processing Record 41 of Set 8 | mulleriyawa
# Processing Record 42 of Set 8 | todos santos
# Processing Record 43 of Set 8 | bambous virieux
# Processing Record 44 of Set 8 | elizabeth city
# Processing Record 45 of Set 8 | miri
# Processing Record 46 of Set 8 | comodoro rivadavia
# Processing Record 47 of Set 8 | longyearbyen
# Processing Record 48 of Set 8 | chongwe
# Processing Record 49 of Set 8 | natal
# Processing Record 50 of Set 8 | americo brasiliense
# Processing Record 1 of Set 9 | wamba
# Processing Record 2 of Set 9 | kartaly
# Processing Record 3 of Set 9 | vanavara
# Processing Record 4 of Set 9 | homei
# City not found. Skipping...
# Processing Record 5 of Set 9 | charters towers
# Processing Record 6 of Set 9 | namatanai
# Processing Record 7 of Set 9 | mantua
# Processing Record 8 of Set 9 | andros town
# Processing Record 9 of Set 9 | bakchar
# Processing Record 10 of Set 9 | saint-pierre
# Processing Record 11 of Set 9 | alice springs
# Processing Record 12 of Set 9 | saint anthony
# Processing Record 13 of Set 9 | witu
# Processing Record 14 of Set 9 | xiaoshi
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | chupa
# Processing Record 17 of Set 9 | severnoye
# Processing Record 18 of Set 9 | hithadhoo
# Processing Record 19 of Set 9 | mao
# Processing Record 20 of Set 9 | aasiaat
# Processing Record 21 of Set 9 | ixtapa
# Processing Record 22 of Set 9 | yulara
# Processing Record 23 of Set 9 | nanortalik
# Processing Record 24 of Set 9 | delhi
# Processing Record 25 of Set 9 | boende
# Processing Record 26 of Set 9 | manta
# Processing Record 27 of Set 9 | colares
# Processing Record 28 of Set 9 | broome
# Processing Record 29 of Set 9 | xinyu
# Processing Record 30 of Set 9 | saint-louis
# Processing Record 31 of Set 9 | payo
# Processing Record 32 of Set 9 | cap malheureux
# Processing Record 33 of Set 9 | tonala
# Processing Record 34 of Set 9 | yangambi
# Processing Record 35 of Set 9 | melbu
# Processing Record 36 of Set 9 | haines junction
# Processing Record 37 of Set 9 | camacha
# Processing Record 38 of Set 9 | tumut
# Processing Record 39 of Set 9 | srednekolymsk
# Processing Record 40 of Set 9 | ossora
# Processing Record 41 of Set 9 | yenagoa
# Processing Record 42 of Set 9 | norman wells
# Processing Record 43 of Set 9 | llanes
# Processing Record 44 of Set 9 | sibolga
# Processing Record 45 of Set 9 | kurtamysh
# Processing Record 46 of Set 9 | yaan
# Processing Record 47 of Set 9 | ornskoldsvik
# Processing Record 48 of Set 9 | southbridge
# Processing Record 49 of Set 9 | bhuj
# Processing Record 50 of Set 9 | krylovskaya
# Processing Record 1 of Set 10 | tambura
# Processing Record 2 of Set 10 | carballo
# Processing Record 3 of Set 10 | alor setar
# Processing Record 4 of Set 10 | kyra
# Processing Record 5 of Set 10 | virginia beach
# Processing Record 6 of Set 10 | tondano
# Processing Record 7 of Set 10 | gilgit
# Processing Record 8 of Set 10 | karymskoye
# Processing Record 9 of Set 10 | dauis
# Processing Record 10 of Set 10 | lagoa
# Processing Record 11 of Set 10 | marzuq
# Processing Record 12 of Set 10 | jaguey grande
# Processing Record 13 of Set 10 | east london
# Processing Record 14 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 10 | west wendover
# Processing Record 16 of Set 10 | sokoto
# Processing Record 17 of Set 10 | suksun
# Processing Record 18 of Set 10 | viedma
# Processing Record 19 of Set 10 | strezhevoy
# Processing Record 20 of Set 10 | xai-xai
# Processing Record 21 of Set 10 | boyle
# Processing Record 22 of Set 10 | jinchang
# Processing Record 23 of Set 10 | bulbucata
# Processing Record 24 of Set 10 | tibati
# Processing Record 25 of Set 10 | quatre cocos
# Processing Record 26 of Set 10 | merced
# Processing Record 27 of Set 10 | kavieng
# Processing Record 28 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 29 of Set 10 | coahuayana
# Processing Record 30 of Set 10 | palauig
# Processing Record 31 of Set 10 | tobol
# Processing Record 32 of Set 10 | milas
# Processing Record 33 of Set 10 | menongue
# Processing Record 34 of Set 10 | katangli
# Processing Record 35 of Set 10 | dali
# Processing Record 36 of Set 10 | mersing
# Processing Record 37 of Set 10 | bengkulu
# Processing Record 38 of Set 10 | ibirama
# Processing Record 39 of Set 10 | katsuura
# Processing Record 40 of Set 10 | puerto madero
# Processing Record 41 of Set 10 | hit
# Processing Record 42 of Set 10 | kwinana
# Processing Record 43 of Set 10 | gizo
# Processing Record 44 of Set 10 | belyy yar
# Processing Record 45 of Set 10 | manthani
# Processing Record 46 of Set 10 | banamba
# Processing Record 47 of Set 10 | luau
# Processing Record 48 of Set 10 | visby
# Processing Record 49 of Set 10 | doha
# Processing Record 50 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 11 | makakilo city
# Processing Record 2 of Set 11 | kushmurun
# Processing Record 3 of Set 11 | rab
# City not found. Skipping...
# Processing Record 4 of Set 11 | chapais
# Processing Record 5 of Set 11 | nuuk
# Processing Record 6 of Set 11 | takoradi
# Processing Record 7 of Set 11 | lekoni
# Processing Record 8 of Set 11 | perelyub
# Processing Record 9 of Set 11 | the pas
# Processing Record 10 of Set 11 | warrnambool
# Processing Record 11 of Set 11 | caibarien
# Processing Record 12 of Set 11 | fortuna
# Processing Record 13 of Set 11 | vao
# Processing Record 14 of Set 11 | aransas pass
# Processing Record 15 of Set 11 | mana
# Processing Record 16 of Set 11 | guerrero
# Processing Record 17 of Set 11 | dingle
# Processing Record 18 of Set 11 | kidal
# Processing Record 19 of Set 11 | killam
# Processing Record 20 of Set 11 | kabarnet
# Processing Record 21 of Set 11 | cayenne
# Processing Record 22 of Set 11 | tuscaloosa
# Processing Record 23 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 11 | kaeo
# Processing Record 25 of Set 11 | guayanilla
# Processing Record 26 of Set 11 | ormara
# Processing Record 27 of Set 11 | ratnagiri
# Processing Record 28 of Set 11 | kununurra
# Processing Record 29 of Set 11 | guane
# Processing Record 30 of Set 11 | port augusta
# Processing Record 31 of Set 11 | bay roberts
# Processing Record 32 of Set 11 | glens falls
# Processing Record 33 of Set 11 | yongan
# Processing Record 34 of Set 11 | cervo
# Processing Record 35 of Set 11 | chalus
# Processing Record 36 of Set 11 | plattsburgh
# Processing Record 37 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 11 | yungkang
# City not found. Skipping...
# Processing Record 39 of Set 11 | tabuk
# Processing Record 40 of Set 11 | agadez
# Processing Record 41 of Set 11 | zherdevka
# Processing Record 42 of Set 11 | columbus
# Processing Record 43 of Set 11 | bimbo
# Processing Record 44 of Set 11 | neuquen
# Processing Record 45 of Set 11 | nicolas bravo
# Processing Record 46 of Set 11 | shelburne
# Processing Record 47 of Set 11 | dori
# Processing Record 48 of Set 11 | weligama
# Processing Record 49 of Set 11 | temizhbekskiy
# Processing Record 50 of Set 11 | cairns
# Processing Record 1 of Set 12 | shubarkuduk
# Processing Record 2 of Set 12 | abong mbang
# Processing Record 3 of Set 12 | manicore
# Processing Record 4 of Set 12 | kedrovyy
# Processing Record 5 of Set 12 | ishim
# Processing Record 6 of Set 12 | korhogo
# Processing Record 7 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 8 of Set 12 | roebourne
# Processing Record 9 of Set 12 | port hardy
# Processing Record 10 of Set 12 | roura
# Processing Record 11 of Set 12 | kovdor
# Processing Record 12 of Set 12 | troitskoye
# Processing Record 13 of Set 12 | pak phanang
# Processing Record 14 of Set 12 | voyvozh
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | vilhena
# Processing Record 17 of Set 12 | sola
# Processing Record 18 of Set 12 | lasa
# Processing Record 19 of Set 12 | bilibino
# Processing Record 20 of Set 12 | yuzhou
# Processing Record 21 of Set 12 | urumqi
# Processing Record 22 of Set 12 | galitsy
# Processing Record 23 of Set 12 | poya
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | kilindoni
# Processing Record 26 of Set 12 | paamiut
# Processing Record 27 of Set 12 | naini tal
# Processing Record 28 of Set 12 | taseyevo
# Processing Record 29 of Set 12 | shirokiy
# Processing Record 30 of Set 12 | baykit
# Processing Record 31 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 12 | bayaguana
# Processing Record 34 of Set 12 | guarapari
# Processing Record 35 of Set 12 | manaure
# Processing Record 36 of Set 12 | tautira
# Processing Record 37 of Set 12 | chumikan
# Processing Record 38 of Set 12 | leshukonskoye
# Processing Record 39 of Set 12 | san patricio
# Processing Record 40 of Set 12 | sirjan
# Processing Record 41 of Set 12 | bamiantong
# Processing Record 42 of Set 12 | scarborough
# Processing Record 43 of Set 12 | pasighat
# Processing Record 44 of Set 12 | margate
# Processing Record 45 of Set 12 | lapua
# Processing Record 46 of Set 12 | ambilobe
# Processing Record 47 of Set 12 | berea
# Processing Record 48 of Set 12 | aix-en-provence
# Processing Record 49 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 12 | houston
# Processing Record 1 of Set 13 | hovd
# Processing Record 2 of Set 13 | trairi
# Processing Record 3 of Set 13 | chara
# Processing Record 4 of Set 13 | nyagan
# Processing Record 5 of Set 13 | weihai
# Processing Record 6 of Set 13 | lichinga
# Processing Record 7 of Set 13 | deder
# Processing Record 8 of Set 13 | lakatoro
# Processing Record 9 of Set 13 | jieshi
# Processing Record 10 of Set 13 | kudahuvadhoo
# Processing Record 11 of Set 13 | jalpan
# Processing Record 12 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 13 | isabela
# Processing Record 14 of Set 13 | te anau
# Processing Record 15 of Set 13 | jiuquan
# Processing Record 16 of Set 13 | gravelbourg
# Processing Record 17 of Set 13 | port hawkesbury
# Processing Record 18 of Set 13 | ballina
# Processing Record 19 of Set 13 | toulepleu
# City not found. Skipping...
# Processing Record 20 of Set 13 | boyolangu
# Processing Record 21 of Set 13 | husavik
# Processing Record 22 of Set 13 | bissau
# Processing Record 23 of Set 13 | nishihara
# Processing Record 24 of Set 13 | gigmoto
# Processing Record 25 of Set 13 | madison
# Processing Record 26 of Set 13 | tommot
# Processing Record 27 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 13 | nanning
# Processing Record 29 of Set 13 | zyryanka
# Processing Record 30 of Set 13 | salym
# Processing Record 31 of Set 13 | necochea
# Processing Record 32 of Set 13 | otta
# Processing Record 33 of Set 13 | belfast
# Processing Record 34 of Set 13 | kurchum
# Processing Record 35 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 13 | umm lajj
# Processing Record 37 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 13 | moba
# Processing Record 39 of Set 13 | meulaboh
# Processing Record 40 of Set 13 | tomatlan
# Processing Record 41 of Set 13 | kiama
# Processing Record 42 of Set 13 | andreapol
# Processing Record 43 of Set 13 | araouane
# Processing Record 44 of Set 13 | vysokogornyy
# Processing Record 45 of Set 13 | kahului
# Processing Record 46 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 13 | vetluga
# Processing Record 48 of Set 13 | dawlatabad
# Processing Record 49 of Set 13 | berdigestyakh
# Processing Record 50 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 14 | bichura
# Processing Record 2 of Set 14 | wanning
# Processing Record 3 of Set 14 | henties bay
# Processing Record 4 of Set 14 | iracoubo
# Processing Record 5 of Set 14 | guia de isora
# Processing Record 6 of Set 14 | quime
# Processing Record 7 of Set 14 | yavatmal
# Processing Record 8 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | kolda
# Processing Record 10 of Set 14 | hambantota
# Processing Record 11 of Set 14 | aquiraz
# Processing Record 12 of Set 14 | tharad
# Processing Record 13 of Set 14 | krasnoselkup
# Processing Record 14 of Set 14 | nizhniy tsasuchey
# Processing Record 15 of Set 14 | sakakah
# Processing Record 16 of Set 14 | north las vegas
# Processing Record 17 of Set 14 | ayr
# Processing Record 18 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 14 | osoyoos
# Processing Record 20 of Set 14 | pokaran
# Processing Record 21 of Set 14 | presidencia roque saenz pena
# Processing Record 22 of Set 14 | opuwo
# Processing Record 23 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 14 | pimentel
# Processing Record 25 of Set 14 | iqaluit
# Processing Record 26 of Set 14 | nemuro
# Processing Record 27 of Set 14 | fukuma
# Processing Record 28 of Set 14 | bonavista
# Processing Record 29 of Set 14 | gamba
# Processing Record 30 of Set 14 | adrar
# Processing Record 31 of Set 14 | nome
# Processing Record 32 of Set 14 | koppal
# Processing Record 33 of Set 14 | puerto narino
# Processing Record 34 of Set 14 | riyadh
# Processing Record 35 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 36 of Set 14 | ponta delgada
# Processing Record 37 of Set 14 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 38 of Set 14 | oistins
# Processing Record 39 of Set 14 | zykovo
# Processing Record 40 of Set 14 | de aar
# Processing Record 41 of Set 14 | mangan
# Processing Record 42 of Set 14 | arkhara
# Processing Record 43 of Set 14 | kyshtovka
# Processing Record 44 of Set 14 | beyneu
# Processing Record 45 of Set 14 | conde
# Processing Record 46 of Set 14 | bridlington
# Processing Record 47 of Set 14 | wollongong
# Processing Record 48 of Set 14 | la paz
# Processing Record 49 of Set 14 | zhicheng
# Processing Record 50 of Set 14 | anadyr
# Processing Record 1 of Set 15 | boguchany
# Processing Record 2 of Set 15 | padre bernardo
# Processing Record 3 of Set 15 | chebenki
# Processing Record 4 of Set 15 | boa vista
# Processing Record 5 of Set 15 | tomakomai
# Processing Record 6 of Set 15 | kondinskoye
# Processing Record 7 of Set 15 | stornoway
# Processing Record 8 of Set 15 | imeni poliny osipenko
# Processing Record 9 of Set 15 | takaka
# Processing Record 10 of Set 15 | buchanan
# Processing Record 11 of Set 15 | buala
# Processing Record 12 of Set 15 | camana
# Processing Record 13 of Set 15 | dudinka
# Processing Record 14 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 15 | imbituba
# Processing Record 16 of Set 15 | umm kaddadah
# Processing Record 17 of Set 15 | honiara
# Processing Record 18 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 15 | temir
# Processing Record 20 of Set 15 | batemans bay
# Processing Record 21 of Set 15 | luckenwalde
# Processing Record 22 of Set 15 | arlit
# Processing Record 23 of Set 15 | mazatlan
# Processing Record 24 of Set 15 | kipushi
# Processing Record 25 of Set 15 | port moresby
# Processing Record 26 of Set 15 | mehamn
# Processing Record 27 of Set 15 | sahateni
# Processing Record 28 of Set 15 | tefe
# Processing Record 29 of Set 15 | dongying
# Processing Record 30 of Set 15 | hoopstad
# Processing Record 31 of Set 15 | bumba
# Processing Record 32 of Set 15 | chicama
# Processing Record 33 of Set 15 | hofn
# Processing Record 34 of Set 15 | bom jesus
# Processing Record 35 of Set 15 | portland
# Processing Record 36 of Set 15 | lac du bonnet
# Processing Record 37 of Set 15 | iralaya
# Processing Record 38 of Set 15 | vallenar
# Processing Record 39 of Set 15 | krasnyy yar
# Processing Record 40 of Set 15 | nicoya
# Processing Record 41 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 42 of Set 15 | buy
# Processing Record 43 of Set 15 | gayny
# Processing Record 44 of Set 15 | fonte boa
# Processing Record 45 of Set 15 | ulhasnagar
# Processing Record 46 of Set 15 | hof
# Processing Record 47 of Set 15 | gold coast
# Processing Record 48 of Set 15 | killybegs
# Processing Record 49 of Set 15 | olavarria
# Processing Record 50 of Set 15 | pointe michel
# Processing Record 1 of Set 16 | tilichiki
# Processing Record 2 of Set 16 | iskilip
# Processing Record 3 of Set 16 | mayya
# Processing Record 4 of Set 16 | tulsipur
# Processing Record 5 of Set 16 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 16 | beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Mar Del Plata      AR -38.0023  -57.5575     41.95        77
# 1          Oussouye      SN  12.4850  -16.5469     80.78        72
# 2         Busselton      AU -33.6500  115.3333     56.50        70
# 3        Puksoozero      RU  62.5903   40.6066     58.41        91
# 4            Keuruu      FI  62.2667   24.7000     48.79        98
# 5        Nelson Bay      AU -32.7167  152.1500     52.11        83
# 6          La Ronge      CA  55.1001 -105.2842     62.85        12
# 7      Richards Bay      ZA -28.7830   32.0377     58.68        77
# 8         Kungurtug      RU  50.5994   97.5228     41.92        72
# 9  Puerto Escondido      MX  15.8500  -97.0667     82.36        73
#
#    Cloudiness  Wind Speed Current Description
# 0           0        3.44           clear sky
# 1          46        4.92    scattered clouds
# 2         100        6.46     overcast clouds
# 3          97        3.94     overcast clouds
# 4         100        8.30     overcast clouds
# 5          89        1.01     overcast clouds
# 6           0       16.11           clear sky
# 7           0        5.17           clear sky
# 8          86        7.05     overcast clouds
# 9          80        3.80       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "/Users/lydiagray/Documents/Data Analytics/Unit 6 WeatherPy/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
